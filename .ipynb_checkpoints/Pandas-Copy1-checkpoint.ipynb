# %%
import pandas as pd

# %%
data = pd.read_csv('archive\iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## Separate Data based on Species

# %%
setosa = data[data['Species'] == 'Iris-setosa']
setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
versicolor = data[data['Species'] == 'Iris-versicolor']
versicolor
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
virginica = data[data['Species'] == 'Iris-virginica']
virginica
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %% [markdown]
# ## Find mean of each feature/attribute

# %%
print('Setosa - \n', setosa.mean())
print('Versicolor - \n', versicolor.mean())
print('Virginica - \n', virginica.mean())
# Out:
# Setosa -
#  Id               25.500
# SepalLengthCm     5.006
# SepalWidthCm      3.418
# PetalLengthCm     1.464
# PetalWidthCm      0.244
# dtype: float64
# Versicolor -
#  Id               75.500
# SepalLengthCm     5.936
# SepalWidthCm      2.770
# PetalLengthCm     4.260
# PetalWidthCm      1.326
# dtype: float64
# Virginica -
#  Id               125.500
# SepalLengthCm      6.588
# SepalWidthCm       2.974
# PetalLengthCm      5.552
# PetalWidthCm       2.026
# dtype: float64

# %% [markdown]
# ## Find feature by which you can try to classify these Species
# It will be nice to find one which has max S.D.; In our case it is PetalLengthCm

# %%
setosa_upperlimit = 3
versicolor_upperlimit = 5
virginica_upperlimit = 6

# %%
setosa_new = data[data['PetalLengthCm'] <= setosa_upperlimit]
setosa_new
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    1            5.1           3.5            1.4           0.2
# 1    2            4.9           3.0            1.4           0.2
# 2    3            4.7           3.2            1.3           0.2
# 3    4            4.6           3.1            1.5           0.2
# 4    5            5.0           3.6            1.4           0.2
# 5    6            5.4           3.9            1.7           0.4
# 6    7            4.6           3.4            1.4           0.3
# 7    8            5.0           3.4            1.5           0.2
# 8    9            4.4           2.9            1.4           0.2
# 9   10            4.9           3.1            1.5           0.1
# 10  11            5.4           3.7            1.5           0.2
# 11  12            4.8           3.4            1.6           0.2
# 12  13            4.8           3.0            1.4           0.1
# ...

# %%
len(setosa_new) #Only one error
# Out:
# 51

# %%
x = data[data['PetalLengthCm'] <= versicolor_upperlimit] #Gives both setosa and versicolor
versicolor_new = x[x['PetalLengthCm'] >= setosa_upperlimit]
versicolor_new
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    51            7.0           3.2            4.7           1.4
# 51    52            6.4           3.2            4.5           1.5
# 52    53            6.9           3.1            4.9           1.5
# 53    54            5.5           2.3            4.0           1.3
# 54    55            6.5           2.8            4.6           1.5
# 55    56            5.7           2.8            4.5           1.3
# 56    57            6.3           3.3            4.7           1.6
# 57    58            4.9           2.4            3.3           1.0
# 58    59            6.6           2.9            4.6           1.3
# 59    60            5.2           2.7            3.9           1.4
# 60    61            5.0           2.0            3.5           1.0
# 61    62            5.9           3.0            4.2           1.5
# 62    63            6.0           2.2            4.0           1.0
# ...

# %%
len(versicolor_new) #84 is missing and a few virginica is added, so considerable error
# Out:
# 58

# %%
y = data[data['PetalLengthCm'] <= virginica_upperlimit] #Gives both setosa and versicolor
virginica_new = y[y['PetalLengthCm'] >= versicolor_upperlimit]
virginica_new
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 77    78            6.7           3.0            5.0           1.7
# 83    84            6.0           2.7            5.1           1.6
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 108  109            6.7           2.5            5.8           1.8
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# 113  114            5.7           2.5            5.0           2.0
# 114  115            5.8           2.8            5.1           2.4
# ...

# %%
len(virginica_new) #many errors here too
# Out:
# 37

# %% [markdown]
# Hence, we are able to separate setosa with less error, other 2 have few or maybe many errors. So, its not classifying using one feature. Therefore, it is a multi-feature classification problem

# %% [markdown]
# There are other features and means too by which we can classify. Ex. mode, median, and etc.

# %%
setosa.mode()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.0           3.4            1.5           0.2  Iris-setosa
# 1    2            5.1           NaN            NaN           NaN          NaN
# 2    3            NaN           NaN            NaN           NaN          NaN
# 3    4            NaN           NaN            NaN           NaN          NaN
# 4    5            NaN           NaN            NaN           NaN          NaN
# 5    6            NaN           NaN            NaN           NaN          NaN
# 6    7            NaN           NaN            NaN           NaN          NaN
# 7    8            NaN           NaN            NaN           NaN          NaN
# 8    9            NaN           NaN            NaN           NaN          NaN
# 9   10            NaN           NaN            NaN           NaN          NaN
# 10  11            NaN           NaN            NaN           NaN          NaN
# ...

# %% [markdown]
# ## Export the files

# %%
setosa_new.to_excel('Setosa_new.xlsx')
versicolor_new.to_excel('Versicolor_new.xlsx')
virginica_new.to_excel('Virginica_new.xlsx')

# %% [markdown]
# ## Now, import the files

# %%
setosa1 = pd.read_excel('Setosa_new.xlsx')
versicolor1 = pd.read_excel('Versicolor_new.xlsx')
virginica1 = pd.read_excel('Virginica_new.xlsx')

# %% [markdown]
# ## Join the DataFrames

# %%
iris = setosa1 + versicolor1 + virginica1
iris
# Out:
#     Unnamed: 0     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0        127.0  130.0           18.8           9.7           11.1
# 1        135.0  138.0           17.3           8.9           11.0
# 2        154.0  157.0           17.9           9.6           12.2
# 3        157.0  160.0           15.9           8.1           10.6
# 4        160.0  163.0           18.6           9.4           11.9
# 5        163.0  166.0           17.4           9.6           11.8
# 6        166.0  169.0           17.4           9.7           11.9
# 7        172.0  175.0           16.6           8.3           10.6
# 8        176.0  179.0           17.5           9.0           11.1
# 9        179.0  182.0           16.5           8.5           10.7
# 10       182.0  185.0           17.2           8.7           10.5
# 11       185.0  188.0           16.4           8.9           10.8
# 12       188.0  191.0           16.6           8.0           10.5
# ...

# %%
iris = pd.concat([setosa1, versicolor1, virginica1])

# %%
iris
# Out:
#     Unnamed: 0   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0            0    1            5.1           3.5            1.4           0.2
# 1            1    2            4.9           3.0            1.4           0.2
# 2            2    3            4.7           3.2            1.3           0.2
# 3            3    4            4.6           3.1            1.5           0.2
# 4            4    5            5.0           3.6            1.4           0.2
# ..         ...  ...            ...           ...            ...           ...
# 32         145  146            6.7           3.0            5.2           2.3
# 33         146  147            6.3           2.5            5.0           1.9
# 34         147  148            6.5           3.0            5.2           2.0
# 35         148  149            6.2           3.4            5.4           2.3
# 36         149  150            5.9           3.0            5.1           1.8
#
#            Species
# ...

# %% [markdown]
# Observe that there are lesser rows

# %% [markdown]
# ## Drop duplicates

# %% [markdown]
# There are a few rows which came in 2 DataFrames rather than one, hence we want to drop them

# %%
iris.drop_duplicates()
# Out:
#     Unnamed: 0   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0            0    1            5.1           3.5            1.4           0.2
# 1            1    2            4.9           3.0            1.4           0.2
# 2            2    3            4.7           3.2            1.3           0.2
# 3            3    4            4.6           3.1            1.5           0.2
# 4            4    5            5.0           3.6            1.4           0.2
# ..         ...  ...            ...           ...            ...           ...
# 31         144  145            6.7           3.3            5.7           2.5
# 32         145  146            6.7           3.0            5.2           2.3
# 34         147  148            6.5           3.0            5.2           2.0
# 35         148  149            6.2           3.4            5.4           2.3
# 36         149  150            5.9           3.0            5.1           1.8
#
#            Species
# ...

# %% [markdown]
# We can observe that there are 5 more rows gone

# %% [markdown]
# We can also drop duplicates based on feature -

# %%
iris.drop_duplicates('SepalLengthCm')
# Out:
#     Unnamed: 0   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0            0    1            5.1           3.5            1.4           0.2
# 1            1    2            4.9           3.0            1.4           0.2
# 2            2    3            4.7           3.2            1.3           0.2
# 3            3    4            4.6           3.1            1.5           0.2
# 4            4    5            5.0           3.6            1.4           0.2
# 5            5    6            5.4           3.9            1.7           0.4
# 8            8    9            4.4           2.9            1.4           0.2
# 11          11   12            4.8           3.4            1.6           0.2
# 13          13   14            4.3           3.0            1.1           0.1
# 14          14   15            5.8           4.0            1.2           0.2
# 15          15   16            5.7           4.4            1.5           0.4
# ...

# %%
len(iris.drop_duplicates('SepalLengthCm'))
# Out:
# 30

# %%
iris.to_excel('Iris_New.xlsx')
